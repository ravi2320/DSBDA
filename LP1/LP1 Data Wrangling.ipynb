# %% [markdown]
# # LA1 Data Wrangling-I

# %%
#import pandas
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1 Classification
# 0     7.99585  417.114              1
# 1     4.06405  468.786              1
# ...

# %%
df.isnull()
# Out:
#        Age    BMI  Glucose  Insulin   HOMA  Leptin  Adiponectin  Resistin  \
# 0    False  False    False    False  False   False        False     False
# 1    False  False    False    False  False   False        False     False
# 2    False  False    False    False  False   False        False     False
# 3    False  False    False    False  False   False        False     False
# 4    False  False    False    False  False   False        False     False
# ..     ...    ...      ...      ...    ...     ...          ...       ...
# 111  False  False    False    False  False   False        False     False
# 112  False  False    False    False  False   False        False     False
# 113  False  False    False    False  False   False        False     False
# 114  False  False    False    False  False   False        False     False
# 115  False  False    False    False  False   False        False     False
#
#      MCP.1  Classification
# 0    False           False
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# BMI               0
# Glucose           0
# Insulin           0
# HOMA              0
# Leptin            0
# Adiponectin       0
# Resistin          0
# MCP.1             0
# Classification    0
# dtype: int64

# %%
df.notnull()
# Out:
#       Age   BMI  Glucose  Insulin  HOMA  Leptin  Adiponectin  Resistin  MCP.1  \
# 0    True  True     True     True  True    True         True      True   True
# 1    True  True     True     True  True    True         True      True   True
# 2    True  True     True     True  True    True         True      True   True
# 3    True  True     True     True  True    True         True      True   True
# 4    True  True     True     True  True    True         True      True   True
# ..    ...   ...      ...      ...   ...     ...          ...       ...    ...
# 111  True  True     True     True  True    True         True      True   True
# 112  True  True     True     True  True    True         True      True   True
# 113  True  True     True     True  True    True         True      True   True
# 114  True  True     True     True  True    True         True      True   True
# 115  True  True     True     True  True    True         True      True   True
#
#      Classification
# ...

# %%
df.notnull().sum()
# Out:
# Age               116
# BMI               116
# Glucose           116
# Insulin           116
# HOMA              116
# Leptin            116
# Adiponectin       116
# Resistin          116
# MCP.1             116
# Classification    116
# dtype: int64

# %%
df.describe()
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1
# count   116.000000  116.000000   116.000000
# mean     10.180874   14.725966   534.647000
# std       6.843341   12.390646   345.912663
# min       1.656020    3.210000    45.843000
# ...

# %%
df.size
# Out:
# 1160

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (116, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 9.2+ KB

# %%
df = df.dropna()
# Out:
#      Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0     48  23.500000       70    2.707  0.467409   8.8071     9.702400
# 1     83  20.690495       92    3.115  0.706897   8.8438     5.429285
# 2     82  23.124670       91    4.498  1.009651  17.9393    22.432040
# 3     68  21.367521       77    3.226  0.612725   9.8827     7.169560
# 4     86  21.111111       92    3.549  0.805386   6.6994     4.819240
# ..   ...        ...      ...      ...       ...      ...          ...
# 111   45  26.850000       92    3.330  0.755688  54.6800    12.100000
# 112   62  26.840000      100    4.530  1.117400  12.4500    21.420000
# 113   65  32.050000       97    5.730  1.370998  61.4800    22.540000
# 114   72  25.590000       82    2.820  0.570392  24.9600    33.750000
# 115   86  27.180000      138   19.910  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1 Classification
# 0     7.99585  417.114              1
# 1     4.06405  468.786              1
# ...

# %%
df.Age.astype(float)
# Out:
# 0      48.0
# 1      83.0
# 2      82.0
# 3      68.0
# 4      86.0
#        ...
# 111    45.0
# 112    62.0
# 113    65.0
# 114    72.0
# 115    86.0
# Name: Age, Length: 116, dtype: float64

# %%
df.Age = df.Age.astype(float)

# %%
df
# Out:
#       Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0    48.0  23.500000       70        2  0.467409   8.8071     9.702400
# 1    83.0  20.690495       92        3  0.706897   8.8438     5.429285
# 2    82.0  23.124670       91        4  1.009651  17.9393    22.432040
# 3    68.0  21.367521       77        3  0.612725   9.8827     7.169560
# 4    86.0  21.111111       92        3  0.805386   6.6994     4.819240
# ..    ...        ...      ...      ...       ...      ...          ...
# 111  45.0  26.850000       92        3  0.755688  54.6800    12.100000
# 112  62.0  26.840000      100        4  1.117400  12.4500    21.420000
# 113  65.0  32.050000       97        5  1.370998  61.4800    22.540000
# 114  72.0  25.590000       82        2  0.570392  24.9600    33.750000
# 115  86.0  27.180000      138       19  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1 Classification
# 0     7.99585  417.114              1
# ...

# %%
df.groupby(by=['Age']).size()
# Out:
# Age
# 24.0    1
# 25.0    1
# 28.0    1
# 29.0    2
# 32.0    1
# 34.0    3
# 35.0    2
# 36.0    2
# 38.0    2
# 40.0    2
# 41.0    1
# 42.0    2
# 43.0    3
# 44.0    4
# 45.0    7
# 46.0    3
# 47.0    1
# 48.0    4
# 49.0    5
# 50.0    1
# 51.0    4
# 52.0    1
# 53.0    1
# 54.0    3
# 55.0    1
# 57.0    1
# 58.0    1
# 59.0    2
# 60.0    2
# 61.0    1
# 62.0    2
# 64.0    2
# 65.0    3
# 66.0    5
# 67.0    1
# 68.0    3
# 69.0    5
# 71.0    3
# 72.0    3
# 73.0    2
# 74.0    1
# 75.0    4
# 76.0    4
# 77.0    2
# 78.0    1
# 81.0    1
# 82.0    2
# 83.0    1
# 85.0    2
# 86.0    3
# 89.0    1
# dtype: int64

# %%
df.dtypes
# Out:
# Age               float64
# BMI               float64
# Glucose             int64
# Insulin             int32
# HOMA              float64
# Leptin            float64
# Adiponectin       float64
# Resistin          float64
# MCP.1             float64
# Classification     object
# dtype: object

# %%
df.sort_values('Age')
# Out:
#       Age        BMI  Glucose  Insulin       HOMA   Leptin  Adiponectin  \
# 13   24.0  18.670000       88        6   1.330000   8.8800    36.060000
# 12   25.0  22.860000       82        4   0.827271  20.4500    23.670000
# 32   28.0  35.855815       87        8   1.840410  68.5102     4.794200
# 22   29.0  32.270788       84        5   1.203832  45.6196     6.209635
# 11   29.0  23.010000       82        5   1.145436  35.5900    26.720000
# ..    ...        ...      ...      ...        ...      ...          ...
# 87   85.0  27.688778      196       51  25.050342  70.8824     7.901685
# 4    86.0  21.111111       92        3   0.805386   6.6994     4.819240
# 78   86.0  26.666667      201       41  20.630734  47.6470     5.357135
# 115  86.0  27.180000      138       19   6.777364  90.2800    14.110000
# 6    89.0  22.700000       77        4   0.890787   6.9640     5.589865
#
#      Resistin     MCP.1 Classification
# 13    6.85000   632.220              1
# ...

# %%
df.sort_values('Age', ascending=False)
# Out:
#       Age        BMI  Glucose  Insulin       HOMA   Leptin  Adiponectin  \
# 6    89.0  22.700000       77        4   0.890787   6.9640     5.589865
# 115  86.0  27.180000      138       19   6.777364  90.2800    14.110000
# 78   86.0  26.666667      201       41  20.630734  47.6470     5.357135
# 4    86.0  21.111111       92        3   0.805386   6.6994     4.819240
# 49   85.0  26.600000       96        4   1.056602   7.8500     7.931700
# ..    ...        ...      ...      ...        ...      ...          ...
# 22   29.0  32.270788       84        5   1.203832  45.6196     6.209635
# 11   29.0  23.010000       82        5   1.145436  35.5900    26.720000
# 32   28.0  35.855815       87        8   1.840410  68.5102     4.794200
# 12   25.0  22.860000       82        4   0.827271  20.4500    23.670000
# 13   24.0  18.670000       88        6   1.330000   8.8800    36.060000
#
#      Resistin     MCP.1 Classification
# 6    12.93610  1256.083              1
# ...

# %%
df.rename(columns={'Age':'Years Old'})
# Out:
#      Years Old        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  \
# 0         48.0  23.500000       70        2  0.467409   8.8071     9.702400
# 1         83.0  20.690495       92        3  0.706897   8.8438     5.429285
# 2         82.0  23.124670       91        4  1.009651  17.9393    22.432040
# 3         68.0  21.367521       77        3  0.612725   9.8827     7.169560
# 4         86.0  21.111111       92        3  0.805386   6.6994     4.819240
# ..         ...        ...      ...      ...       ...      ...          ...
# 111       45.0  26.850000       92        3  0.755688  54.6800    12.100000
# 112       62.0  26.840000      100        4  1.117400  12.4500    21.420000
# 113       65.0  32.050000       97        5  1.370998  61.4800    22.540000
# 114       72.0  25.590000       82        2  0.570392  24.9600    33.750000
# 115       86.0  27.180000      138       19  6.777364  90.2800    14.110000
#
#      Resistin    MCP.1 Classification
# ...
